# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# !unzip data-for-datavis.zip
# Out:
# Archive:  data-for-datavis.zip
#   inflating: cancer_b.csv
#   inflating: candy.csv
#   inflating: iris_virginica.csv
#   inflating: insurance.csv
#   inflating: museum_visitors.csv
#   inflating: fifa.csv
#   inflating: flight_delays.csv
#   inflating: iris.csv
#   inflating: ign_scores.csv
#   inflating: iris_versicolor.csv
#   inflating: iris_setosa.csv
#   inflating: spotify.csv
#   inflating: cancer_m.csv

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
iris = pd.read_csv("/content/iris.csv",index_col="Id")

# %% [markdown]
# 1.   Without the assumption of Normal Dist
# 2.   Flag unusually distant points
# 3.   Dint want to mark too many points extreme
# 4.   Simple visual method
#
# Ouliers

# %%
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
iris.describe() #Quantiles
# Out:
#        Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        Petal Width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
6.400000-5.100000
# Out:
# 1.3000000000000007

# %%
ax = sns.boxplot(data=iris)

# %%
ax = sns.boxplot(data=iris,orient='h')

# %%
#Std - Spread of data.. - Standard Deviation
#Box - Turkeys Box and Outlier Defenitions - Extreme values | Mild outliers = 1.5 | Extreme outliers = 3.0

# %%
sns.displot(iris['Sepal Length (cm)'])

# %%
sns.displot(iris['Sepal Length (cm)'],kde = True) #KDE - Kernel Density Estimate

# %%
insurance = pd.read_csv("/content/insurance.csv")

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Bi-variate

# %%
sns.scatterplot(x=insurance['bmi'],y=insurance['charges'])  #Co-Vary to gether..
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ### Multi-Variate Analysis

# %%
sns.scatterplot(x=insurance['bmi'],y=insurance['charges'],hue = insurance['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x='bmi',y='charges',hue ='smoker', data = insurance)

# %% [markdown]
# #For quantifying how much two variables co-vary to gether.. Or how close are these two variables? +ve -ve???
#
# #I need to understand how two varibles vary on average between each other..

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %%
insurance_numbers = insurance.select_dtypes(include = "number")

# %%
insurance_numbers.cov() #Range #Multi-variate / Bivariate Analysis
# Out:
#                    age           bmi    children       charges
# age         197.401387      9.362337    0.719303  5.087480e+04
# bmi           9.362337     37.187884    0.093795  1.464730e+04
# children      0.719303      0.093795    1.453213  9.926742e+02
# charges   50874.802298  14647.304426  992.674197  1.466524e+08

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#If no causation Covariance will be Low!
sns.scatterplot(x='bmi',y='children', data = insurance)  #No relation (-inf, +inf) Covariance Explains Causation
# Out:
# <Axes: xlabel='bmi', ylabel='children'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#limit of Correlation is between (-1 to 1)
#X & Y: Z Correlation does not capture  Z Inc -> X Inc | Z Inc -> Y Inc
insurance_numbers.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)
