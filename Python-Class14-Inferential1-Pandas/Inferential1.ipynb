# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(titanic["age"].dropna())
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(titanic["age"].dropna(),bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(titanic["fare"].dropna())
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
for col in ['age','fare']:
  titanic[col+'_z'] = (titanic[col] - titanic[col].mean()) / titanic[col].std()

# %%
titanic[['age','fare','age_z','fare_z']].head()
# Out:
#     age     fare     age_z    fare_z
# 0  22.0   7.2500 -0.530005 -0.502163
# 1  38.0  71.2833  0.571430  0.786404
# 2  26.0   7.9250 -0.254646 -0.488580
# 3  35.0  53.1000  0.364911  0.420494
# 4  35.0   8.0500  0.364911 -0.486064

# %%
titanic["age"].std()
# Out:
# 14.526497332334044

# %%
sns.histplot(titanic["age"].dropna())
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.histplot(titanic["age_z"].dropna()) #Z scale
# Out:
# <Axes: xlabel='age_z', ylabel='Count'>

# %%
sns.histplot(titanic["age"].dropna())
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
z = titanic['age_z'].dropna()
fig, ax = plt.subplots()
sns.histplot(z, bins = 30, kde = True)
for k in [1,2,3]:
  ax.axvline(-k, linestyle = '--',color = 'r')
  ax.axvline(k, linestyle = '--',color = 'r')
plt.show()

# %%
titanic['age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
titanic['age'].std()
# Out:
# 14.526497332334044

# %%
print(f"The 68% of the passengers were between {29-14.52} - {29+14.52}")
# Out:
# The 68% of the passengers were between 14.48 - 43.519999999999996

# %%
print(f"The 95% of the passengers were between {(0)} - {(29+2*(14.52))}") #Z -> 1.96
# Out:
# The 95% of the passengers were between 0 - 58.04

# %%
#I have a person with Age - 'x' (80), Could this person have travelled in Titanic? 95
#very very very less likely

# %%
#Exit Poll Survey - Parties x, y and z - Party 'Y' is leading #Sample from the population
#Election Results come - Parties x, y and z - Party 'Y' won #Population
#Learnt different ways to Describe my data - Descriptive statistics
#MAke inference about my population with my sample data in hand - Inferential Statistics

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.histplot(titanic["age"].dropna(),kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
titanic["age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
z = (30-titanic["age"].mean()) /titanic["age"].std()

# %%
z
# Out:
# np.float64(0.02071265674426938)

# %%
from scipy.stats import norm

# %%
norm.cdf(30,titanic["age"].mean(),titanic["age"].std())
# Out:
# np.float64(0.5082625637177163)

# %%
P(X <= x) = P(X <= 40)

# %%
z = (40-titanic["age"].mean()) /titanic["age"].std()

# %%
z
# Out:
# np.float64(0.7091098505909467)

# %%
#NORMAL DISTRIBUTION - CUMULATIVE DISTRIBUTION FUNCTION

# %%
norm.cdf(40,titanic["age"].mean(),titanic["age"].std())
# Out:
# np.float64(0.7608718447319547)

# %%
From the table: 0.7852
